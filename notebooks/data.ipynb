# %%
import nntools.dataset as D
from nntools.dataset.utils.ops import split
import numpy as np
from cornea.data.datamodule import CorneaDatamodule

root_img = "/home/clement/Documents/data/Cornea/"
datamodule = CorneaDatamodule(
    root_img, batch_size=1, num_workers=0, img_size=(416, 1280)
)
datamodule.prepare_data()

# %%
datamodule.val.filenames
# Out:
# {'image': ['GALOTA_GIORGIO__2160587_19810927_Male_HD Cornea_20231116122047_OD_20240705154113.jpg',
#   'GALOTA_GIORGIO__2160587_19810927_Male_HD Cornea_20231116122059_OD_20240705154108.jpg',
#   'GALOTA_GIORGIO__2160587_19810927_Male_HD Cornea_20231116122111_OD_20240705154103.jpg',
#   'GALOTA_GIORGIO__2160587_19810927_Male_HD Cornea_20231116122140_OD_20240705154058.jpg',
#   'GALOTA_GIORGIO__2160587_19810927_Male_HD Cornea_20231116122202_OD_20240705154054.jpg',
#   'GALOTA_GIORGIO__2160587_19810927_Male_HD Cornea_20231116122225_OD_20240705154048.jpg',
#   'MARTINEZ PETRO_ALEJANDRA__2135549_19870627_Female_HD Cornea_20230424123910_OD_20240705152122.jpg',
#   'MARTINEZ PETRO_ALEJANDRA__2135549_19870627_Female_HD Cornea_20230424123923_OD_20240705152116.jpg',
#   'MARTINEZ PETRO_ALEJANDRA__2135549_19870627_Female_HD Cornea_20230424123937_OD_20240705152108.jpg',
#   'MARTINEZ PETRO_ALEJANDRA__2135549_19870627_Female_HD Cornea_20230424124003_OD_20240705152048.jpg',
# ...
